# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\kumar\Downloads\StudentPerformanceFactors.csv")

# %%
df=data.copy()

# %%
df.head(30)
# Out:
#     Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0              23          84                  Low                High
# 1              19          64                  Low              Medium
# 2              24          98               Medium              Medium
# 3              29          89                  Low              Medium
# 4              19          92               Medium              Medium
# 5              19          88               Medium              Medium
# 6              29          84               Medium                 Low
# 7              25          78                  Low                High
# 8              17          94               Medium                High
# 9              23          98               Medium              Medium
# 10             17          97               Medium                High
# 11             21          83               Medium              Medium
# ...

# %%
df.dropna(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns="index",inplace=True)

# %%
#sns.pairplot(data=df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               5783 non-null   int64
#  1   Attendance                  5783 non-null   int64
#  2   Parental_Involvement        5783 non-null   object
#  3   Access_to_Resources         5783 non-null   object
#  4   Extracurricular_Activities  5783 non-null   object
#  5   Sleep_Hours                 5783 non-null   int64
#  6   Previous_Scores             5783 non-null   int64
#  7   Motivation_Level            5783 non-null   object
#  8   Internet_Access             5783 non-null   object
#  9   Tutoring_Sessions           5783 non-null   int64
#  10  Family_Income               5783 non-null   object
#  11  Teacher_Quality             5783 non-null   object
#  12  School_Type                 5783 non-null   object
# ...

# %%
df["Teacher_Quality"].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6378.000000  6378.000000  6378.000000      6378.000000
# mean       19.977109    80.020853     7.034964        75.066165
# std         5.985460    11.550723     1.468033        14.400389
# min         1.000000    60.000000     4.000000        50.000000
# 25%        16.000000    70.000000     6.000000        63.000000
# 50%        20.000000    80.000000     7.000000        75.000000
# 75%        24.000000    90.000000     8.000000        88.000000
# max        44.000000   100.000000    10.000000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6378.000000        6378.000000  6378.000000
# mean            1.495296           2.972719    67.252117
# std             1.233984           1.028926     3.914217
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
q1=df["Exam_Score"].quantile(0.25)
q3=df["Exam_Score"].quantile(0.75)
IQR=q3-q1

# %%
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)

# %%
df=df[(df["Exam_Score"]<max) & (df["Exam_Score"]>min)]

# %%
q1=df["Tutoring_Sessions"].quantile(0.25)
q3=df["Tutoring_Sessions"].quantile(0.75)
IQR=q3-q1
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)

# %%
df=df[(df["Tutoring_Sessions"]<max) & (df["Tutoring_Sessions"]>min)]

# %%
df.reset_index(inplace=True)

# %%
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder

# %%
list=[['High','Medium','Low']]

# %%
ord=OrdinalEncoder(categories=list)

# %%
df["Teacher_Quality1"]=ord.fit_transform(df[["Teacher_Quality"]])

# %%
df.drop(columns="index",inplace=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_2228\2774306420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns="index",inplace=True)

# %%
one=OneHotEncoder(sparse_output=False)
i=one.fit_transform(df[["Internet_Access"]])

# %%
i1=one.fit_transform(df[["School_Type"]])

# %%
i2=one.fit_transform(df[["Gender"]])

# %%
x=pd.DataFrame(i,columns=one.get_feature_names_out())

# %%
x1=pd.DataFrame(i1,columns=one.get_feature_names_out())

# %%
x2=pd.DataFrame(i2,columns=one.get_feature_names_out())

# %%
df=pd.concat([df,x2],axis=1)

# %%
df=pd.concat([df,x],axis=1)

# %%
df=pd.concat([df,x1],axis=1)

# %%
df.head(4)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
#
#   Internet_Access  Tutoring_Sessions  ... Distance_from_Home  Gender  \
# 0             Yes                  0  ...               Near    Male
# 1             Yes                  2  ...           Moderate  Female
# ...

# %%
data.shape,df.shape
# Out:
# ((6607, 20), (5783, 25))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x=df[["Hours_Studied","Attendance","Sleep_Hours","Previous_Scores","Tutoring_Sessions","Physical_Activity","Internet_Access_No","Internet_Access_Yes","School_Type_Private","School_Type_Public","Gender_Female","Gender_Male"]]
y=df["Exam_Score"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
lg=LinearRegression()
lg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lg.score(x_test,y_test)
# Out:
# 0.8000348516545087

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
np.sqrt(mean_squared_error(y_test,lg.predict(x_test)))
# Out:
# np.float64(1.3901877307052732)

# %%
r2_score(y_test,lg.predict(x_test))
# Out:
# 0.8000348516545087

# %%
lg.predict([[14,84,7,81,0,2,0,1,0,1,1,0]])
# Out:
# c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65.58597546])

# %%
x_test.head(10)
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 1886             20          90            9               79
# 2067             18          95            7               96
# 3334             22          80            9               51
# 4065             21          74            8               79
# 156              31          84            9               87
# 4853             13          93            7               51
# 4506             19          92            7               90
# 2215             17          90            8               65
# 5677              8          77            7               90
# 2213             14          84            7               81
#
#       Tutoring_Sessions  Physical_Activity  Internet_Access_No  \
# 1886                  2                  2                 0.0
# 2067                  2                  4                 0.0
# 3334                  2                  3                 0.0
# ...

# %%
y_test.head(10)
# Out:
# 1886    70
# 2067    70
# 3334    68
# 4065    67
# 156     71
# 4853    67
# 4506    70
# 2215    71
# 5677    61
# 2213    66
# Name: Exam_Score, dtype: int64

# %%
x.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Internet_Access_No',
#        'Internet_Access_Yes', 'School_Type_Private', 'School_Type_Public',
#        'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
se=SequentialFeatureSelector(lg,k_features=7,forward=True)

# %%
se.fit(x,y)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=(7, 7),
#                           scoring='r2')

# %%
se.k_score_
# Out:
# np.float64(0.8047075471621208)

# %%
se.k_feature_names_
# Out:
# ('Hours_Studied',
#  'Attendance',
#  'Previous_Scores',
#  'Tutoring_Sessions',
#  'Physical_Activity',
#  'Internet_Access_No',
#  'Internet_Access_Yes')

# %%
se.feature_names
# Out:
# ['Hours_Studied',
#  'Attendance',
#  'Sleep_Hours',
#  'Previous_Scores',
#  'Tutoring_Sessions',
#  'Physical_Activity',
#  'Internet_Access_No',
#  'Internet_Access_Yes',
#  'School_Type_Private',
#  'School_Type_Public',
#  'Gender_Female',
#  'Gender_Male']
