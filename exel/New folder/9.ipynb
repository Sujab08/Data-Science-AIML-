# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\kumar\Downloads\archive (2).zip")

# %%
df.isna().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                           51700
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df["rate"]=df["rate"].str.replace(" ","").tail(20)

# %%
df["rate"]=df["rate"].str.replace("/5","00")
# Out:
# 51697    4.400
# 51698    3.900
# 51699    4.100
# 51700    4.100
# 51701    4.100
# 51702    4.000
# 51703    3.900
# 51704    4.000
# 51705    3.800
# 51706    3.700
# 51707    3.900
# 51708    2.800
# 51709    3.700
# 51710      NaN
# 51711    2.500
# 51712    3.600
# 51713      NaN
# 51714      NaN
# 51715    4.300
# 51716    3.400
# Name: rate, dtype: object

# %%
df.tail(50)
# Out:
#                                                      url  \
# 51667  https://www.zomato.com/bangalore/w-xyz-aloft-h...
# 51668  https://www.zomato.com/bangalore/izakaya-gastr...
# 51669  https://www.zomato.com/bangalore/red-glow-whit...
# 51670  https://www.zomato.com/bangalore/miro-bar-mira...
# 51671  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51672  https://www.zomato.com/bangalore/slounge-lemon...
# 51673  https://www.zomato.com/bangalore/checkered-bar...
# 51674  https://www.zomato.com/bangalore/the-farm-hous...
# 51675  https://www.zomato.com/bangalore/topsy-turvey-...
# 51676  https://www.zomato.com/bangalore/tease-whitefi...
# 51677  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51678  https://www.zomato.com/bangalore/best-brews-fo...
# 51679  https://www.zomato.com/bangalore/unlock-the-re...
# 51680  https://www.zomato.com/bangalore/trinity-club-...
# 51681  https://www.zomato.com/bangalore/chime-sherato...
# ...

# %%
df.isna().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                           51700
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64
