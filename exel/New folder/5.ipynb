# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\kumar\Downloads\archive (1)\Students_Performance_mv.csv")

# %%
df["gender"]=df["gender"].apply(lambda x:"F" if x=="female" else "M")

# %%
c=df.columns
d=[]
for i in c:
    d.append(i.upper())
df.columns=d

# %%
df["RACE/ETHNICITY"]=df["RACE/ETHNICITY"].apply(lambda x: x.capitalize())

# %%
df.dropna(inplace=True)

# %%
df["TEST PREPARATION COURSE"].value_counts()
# Out:
# TEST PREPARATION COURSE
# none         618
# completed    341
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#   GENDER RACE/ETHNICITY PARENTAL LEVEL OF EDUCATION         LUNCH  \
# 0      F        Group b           bachelor's degree      standard
# 1      F        Group c                some college      standard
# 2      F        Group b             master's degree      standard
# 3      M        Group a          associate's degree  free/reduced
# 4      M        Group c                some college      standard
# 5      F        Group b          associate's degree      standard
# 6      F        Group b                some college      standard
# 7      M        Group b                some college  free/reduced
# 8      M        Group d                 high school  free/reduced
# 9      F        Group b                 high school  free/reduced
#
#   TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 959 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   GENDER                       959 non-null    object
#  1   RACE/ETHNICITY               959 non-null    object
#  2   PARENTAL LEVEL OF EDUCATION  959 non-null    object
#  3   LUNCH                        959 non-null    object
#  4   TEST PREPARATION COURSE      959 non-null    object
#  5   MATH SCORE                   959 non-null    int64
#  6   READING SCORE                959 non-null    int64
#  7   WRITING SCORE                959 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 67.4+ KB
