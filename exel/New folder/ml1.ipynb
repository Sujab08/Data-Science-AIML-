# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\kumar\Downloads\Placements_Dataset.csv (1).zip")

# %%
df
# Out:
#               Name of Student  Roll No.  No. of DSA questions  CGPA Knows ML  \
# 0                   Todd Pope     30678                   151  8.52      Yes
# 1                Sandra Brown     49191                    24  1.23      Yes
# 2       Mrs. Amanda Singleton     83519                   333  9.85       No
# 3            Matthew Alvarado     56203                   132  1.96       No
# 4             Christine Smith     82173                   198  9.73      Yes
# ...                       ...       ...                   ...   ...      ...
# 219995          Ashley Conner     36698                   453  8.77       No
# 219996            Samuel Kemp     85027                   375  6.15       No
# 219997        Alexander Payne     92497                    52  2.05       No
# 219998             Sean Bauer     35235                   404  5.63       No
# 219999         Brianna Wilcox     94796                   134  7.49      Yes
#
# ...

# %%
d=df.copy()

# %%
d['Knows ML']=d['Knows ML'].fillna(d['Knows ML'].mode()[0])

# %%
d['Knows Python']=d['Knows Python'].fillna(d['Knows Python'].mode()[0])

# %%
d['Knows JavaScript']=d['Knows JavaScript'].fillna(d['Knows JavaScript'].mode()[0])

# %%
d['Knows HTML']=d['Knows HTML'].fillna(d['Knows HTML'].mode()[0])

# %%
d['Knows CSS']=d['Knows CSS'].fillna(d['Knows CSS'].mode()[0])

# %%
d['Branch of Engineering'].unique()
# Out:
# array(['Computer Science', 'Mechanical Engineering',
#        'Electrical Engineering', 'Civil Engineering'], dtype=object)

# %%
df.head()
# Out:
#          Name of Student  Roll No.  No. of DSA questions  CGPA Knows ML  \
# 0              Todd Pope     30678                   151  8.52      Yes
# 1           Sandra Brown     49191                    24  1.23      Yes
# 2  Mrs. Amanda Singleton     83519                   333  9.85       No
# 3       Matthew Alvarado     56203                   132  1.96       No
# 4        Christine Smith     82173                   198  9.73      Yes
#
#   Knows DSA Knows Python Knows JavaScript Knows HTML Knows CSS Knows Cricket  \
# 0       Yes          Yes              Yes         No       Yes            No
# 1        No           No              Yes         No        No           Yes
# 2       Yes          Yes               No        Yes        No            No
# 3        No          Yes               No        Yes        No            No
# 4       Yes          Yes              Yes        Yes       Yes           Yes
#
#   Knows Dance Participated in College Fest Was in Coding Club  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split
le=LinearRegression()
X=df[['No. of DSA questions','CGPA','No. of backlogs']]
#X=df[['No. of DSA questions']]
y=df['Placement Package']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)
le.fit(X_test,y_test)
result=le.predict(X_test)
#print(le.score(X_test,y_test)*100)

# %%
X_test
# Out:
#         No. of DSA questions  CGPA  No. of backlogs
# 89356                    344  4.72                1
# 51113                    211  0.59                4
# 81421                    122  4.91                3
# 9551                     106  4.01                3
# 122215                   499  1.70                1
# ...                      ...   ...              ...
# 170643                   408  0.17                2
# 116142                   427  4.86                0
# 138879                    71  3.06                5
# 196282                   410  2.05                4
# 151289                    13  7.37                4
#
# [55000 rows x 3 columns]

# %%
y.shape,result.shape
# Out:
# ((220000,), (55000,))

# %% [markdown]
# # model evaluation

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(y_test,result)
mse=mean_squared_error(y_test,result)
rmse=np.sqrt(mse)
r2=r2_score(y_test,result)
print(mae)
print(mse)
print(rmse)
print(r2)
# Out:
# 8.837575931151086
# 126.86888950533684
# 11.263609079923576
# 0.47653604002131744

# %% [markdown]
# # transfer lable into number

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
d['dsa']=le.fit_transform(d['Knows DSA'])

# %%
d['ml']=le.fit_transform(d['Knows ML'])
d['python']=le.fit_transform(d['Knows Python'])
d['js']=le.fit_transform(d['Knows JavaScript'])
d['html']=le.fit_transform(d['Knows HTML'])
d['css']=le.fit_transform(d['Knows CSS'])
d['cricker']=le.fit_transform(d['Knows Cricket'])
d['dance']=le.fit_transform(d['Knows Dance'])
d['fest']=le.fit_transform(d['Participated in College Fest'])
d['clube']=le.fit_transform(d['Was in Coding Club'])

# %%
df
# Out:
#               Name of Student  Roll No.  No. of DSA questions  CGPA Knows ML  \
# 0                   Todd Pope     30678                   151  8.52      Yes
# 1                Sandra Brown     49191                    24  1.23      Yes
# 2       Mrs. Amanda Singleton     83519                   333  9.85       No
# 3            Matthew Alvarado     56203                   132  1.96       No
# 4             Christine Smith     82173                   198  9.73      Yes
# ...                       ...       ...                   ...   ...      ...
# 219995          Ashley Conner     36698                   453  8.77       No
# 219996            Samuel Kemp     85027                   375  6.15       No
# 219997        Alexander Payne     92497                    52  2.05       No
# 219998             Sean Bauer     35235                   404  5.63       No
# 219999         Brianna Wilcox     94796                   134  7.49      Yes
#
# ...

# %%
df.head()
# Out:
#          Name of Student  Roll No.  No. of DSA questions  CGPA Knows ML  \
# 0              Todd Pope     30678                   151  8.52      Yes
# 1           Sandra Brown     49191                    24  1.23      Yes
# 2  Mrs. Amanda Singleton     83519                   333  9.85       No
# 3       Matthew Alvarado     56203                   132  1.96       No
# 4        Christine Smith     82173                   198  9.73      Yes
#
#   Knows DSA Knows Python Knows JavaScript Knows HTML Knows CSS Knows Cricket  \
# 0       Yes          Yes              Yes         No       Yes            No
# 1        No           No              Yes         No        No           Yes
# 2       Yes          Yes               No        Yes        No            No
# 3        No          Yes               No        Yes        No            No
# 4       Yes          Yes              Yes        Yes       Yes           Yes
#
#   Knows Dance Participated in College Fest Was in Coding Club  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220000 entries, 0 to 219999
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Name of Student               220000 non-null  object
#  1   Roll No.                      220000 non-null  int64
#  2   No. of DSA questions          220000 non-null  int64
#  3   CGPA                          220000 non-null  float64
#  4   Knows ML                      220000 non-null  object
#  5   Knows DSA                     220000 non-null  object
#  6   Knows Python                  220000 non-null  object
#  7   Knows JavaScript              220000 non-null  object
#  8   Knows HTML                    220000 non-null  object
#  9   Knows CSS                     220000 non-null  object
#  10  Knows Cricket                 220000 non-null  object
#  11  Knows Dance                   220000 non-null  object
# ...

# %%
d.drop(columns=['Participated in College Fest','Interview Room Temperature'])
# Out:
#               Name of Student  Roll No.  No. of DSA questions  CGPA Knows ML  \
# 0                   Todd Pope     30678                   151  8.52      Yes
# 1                Sandra Brown     49191                    24  1.23      Yes
# 2       Mrs. Amanda Singleton     83519                   333  9.85       No
# 3            Matthew Alvarado     56203                   132  1.96       No
# 4             Christine Smith     82173                   198  9.73      Yes
# ...                       ...       ...                   ...   ...      ...
# 219995          Ashley Conner     36698                   453  8.77       No
# 219996            Samuel Kemp     85027                   375  6.15       No
# 219997        Alexander Payne     92497                    52  2.05       No
# 219998             Sean Bauer     35235                   404  5.63       No
# 219999         Brianna Wilcox     94796                   134  7.49      Yes
#
# ...

# %%
sns.scatterplot(x='No. of DSA questions',y='CGPA',data=d,hue='ml')
plt.show()

# %% [markdown]
# # logistick regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
Z=d[['CGPA']]
a=d['ml']
Z_train,Z_test,a_train,a_test=train_test_split(Z,a,test_size=0.2,random_state=42)
lg=LogisticRegression()
lg.fit(Z_train,a_train)
lg.score(Z_test,a_test)
# Out:
# 0.5115909090909091

# %%
sns.scatterplot(x='CGPA',y='ml',data=d)
plt.show()

# %%
Z_test.head(20)
# Out:
#         CGPA
# 132386  0.05
# 129137  0.62
# 100916  2.32
# 197454  7.33
# 53856   9.34
# 186405  0.65
# 102254  9.10
# 214003  9.71
# 160990  8.55
# 50318   2.11
# 168709  5.71
# 152969  3.59
# 31710   2.79
# 98688   2.14
# 128094  6.59
# 66626   5.02
# 28777   7.69
# 64405   6.02
# 216345  4.06
# 96244   4.36

# %%
lg.predict([[4.06]])
# Out:
# c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
a_test.head(20)
# Out:
# 132386    0
# 129137    1
# 100916    0
# 197454    1
# 53856     0
# 186405    0
# 102254    1
# 214003    0
# 160990    0
# 50318     1
# 168709    1
# 152969    0
# 31710     0
# 98688     0
# 128094    1
# 66626     0
# 28777     1
# 64405     0
# 216345    1
# 96244     0
# Name: ml, dtype: int64

# %%
d.head()
# Out:
#          Name of Student  Roll No.  No. of DSA questions  CGPA Knows ML  \
# 0              Todd Pope     30678                   151  8.52      Yes
# 1           Sandra Brown     49191                    24  1.23      Yes
# 2  Mrs. Amanda Singleton     83519                   333  9.85       No
# 3       Matthew Alvarado     56203                   132  1.96       No
# 4        Christine Smith     82173                   198  9.73      Yes
#
#   Knows DSA Knows Python Knows JavaScript Knows HTML Knows CSS  ... dsa ml  \
# 0       Yes          Yes              Yes         No       Yes  ...   1  1
# 1        No           No              Yes         No        No  ...   0  1
# 2       Yes          Yes               No        Yes        No  ...   1  0
# 3        No          Yes               No        Yes        No  ...   0  0
# 4       Yes          Yes              Yes        Yes       Yes  ...   1  1
#
#   python js  html  css  cricker dance  fest  clube
# ...

# %% [markdown]
# # principle componet analysis(pca)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
x=d[['No. of DSA questions','CGPA','Placement Package']]
ss=StandardScaler()
ss1=ss.fit_transform(x)
ss1
pac=PCA(n_components=2)
pca_result=PCA.fit_transform(ss1)
pca_df=pd.DataFrame(pca_result,columns=['pca1','pca2'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 8
#       6 ss1
#       7 pac=PCA(n_components=2)
# ----> 8 pca_result=PCA.fit_transform(ss1)
#       9 pca_df=pd.DataFrame(pca_result,columns=['pca1','pca2'])
#
# TypeError: PCA.fit_transform() missing 1 required positional argument: 'X'

# %%
plt.hist(x=df['Placement Package'])
plt.show()

# %%
plt.scatter(d['CGPA'],d['Placement Package'])
plt.xlabel('cgpa')
plt.ylabel('package')
plt.show()

# %%
plt.figure(figsize=[6,4])
sns.boxplot(x=d['Placement Package'],color='orange')
plt.show()

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220000 entries, 0 to 219999
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Name of Student               220000 non-null  object
#  1   Roll No.                      220000 non-null  int64
#  2   No. of DSA questions          220000 non-null  int64
#  3   CGPA                          220000 non-null  float64
#  4   Knows ML                      220000 non-null  object
#  5   Knows DSA                     220000 non-null  object
#  6   Knows Python                  220000 non-null  object
#  7   Knows JavaScript              220000 non-null  object
#  8   Knows HTML                    220000 non-null  object
#  9   Knows CSS                     220000 non-null  object
#  10  Knows Cricket                 220000 non-null  object
#  11  Knows Dance                   220000 non-null  object
# ...

# %%
d.describe()
# Out:
#             Roll No.  No. of DSA questions           CGPA  No. of backlogs  \
# count  220000.000000         220000.000000  220000.000000    220000.000000
# mean    54857.740568            250.099414       5.005776         2.497368
# std     25983.468755            144.545550       2.888164         1.707581
# min     10000.000000              0.000000       0.000000         0.000000
# 25%     32394.000000            125.000000       2.500000         1.000000
# 50%     54695.000000            250.000000       5.020000         2.000000
# 75%     77376.000000            375.000000       7.500000         4.000000
# max     99999.000000            500.000000      10.000000         5.000000
#
#        Interview Room Temperature  Age of Candidate  Placement Package  \
# count               220000.000000     220000.000000      220000.000000
# mean                    24.004006         21.497373          20.295666
# std                      3.467504          2.290835          15.597126
# ...

# %%
d.shape
# Out:
# (220000, 30)

# %%
from sklearn.cluster import KMeans
x=d[['CGPA','Placement Package']]
model=KMeans(n_clusters=2,random_state=42,n_init=20)
d['group']=model.fit_predict(x)
dd=d[['CGPA','Placement Package','group']].sort_values(by='group',ascending=True)
plt.figure(figsize=[10,5])
for group in d['group'].unique():
    gd=d[d['group']==group]
    plt.scatter(gd['CGPA'],gd['Placement Package'],label=f'group{group}')
plt.grid()
plt.legend()
plt.show()

# %%
print(dd.head(50))
#print(dd.iloc[20:50])
# Out:
#         CGPA  Placement Package  group
# 219979  0.65              12.35      0
# 219980  1.53               3.10      0
# 219982  4.53               5.37      0
# 219983  0.10               9.05      0
# 219968  4.80              10.19      0
# 219970  4.78              11.42      0
# 219971  6.38              22.03      0
# 219972  8.28              12.48      0
# 219985  4.79               8.84      0
# 219987  3.19               5.17      0
# 219988  3.14               5.86      0
# 219989  8.48              20.34      0
# 219991  2.32               4.90      0
# 219976  0.36               6.80      0
# 219977  2.99              12.49      0
# 219978  6.34              21.63      0
# 143014  2.98              12.58      0
# 219992  4.67               5.53      0
# 219993  4.73               3.51      0
# 219994  1.12               5.50      0
# 219996  6.15              11.00      0
# 219997  2.05               3.82      0
# 219999  7.49              23.08      0
# ...

# %% [markdown]
# # elbow method

# %%
from sklearn.cluster import KMeans
data={
    'Customer':['riya','sujab','gopal','akash','seema','puja'],
    'Age':[20,30,40,22,38,25],
    'Spending':[100,200,300,110,290,130]
}
df=pd.DataFrame(data)

# %% [markdown]
# # markdown

# %%
x=df[['Age','Spending']]
model=KMeans(n_clusters=2,random_state=42,n_init=10)
df['group']=model.fit_predict(x)
plt.figure(figsize=(6,5))
for group in df['group'].unique():
    group_data=df[df['group']==group]
    plt.scatter(group_data['Age'],group_data['Spending'],label=f'group{group}')
plt.legend()
plt.grid(True)
plt.show()
df
# Out:
#   Customer  Age  Spending  group
# 0     riya   20       100      1
# 1    sujab   30       200      1
# 2    gopal   40       300      0
# 3    akash   22       110      1
# 4    seema   38       290      0
# 5     puja   25       130      1

# %% [markdown]
# ## principle componet analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
data={
    'Age':[25,30,35,40,45,50],
    'Income':[30000,40000,50000,60000,70000,80000],
    'Spending':[70,60,50,40,30,20],
    'Saving':[1000,5000,8000,10000,15000,20000]
}
df=pd.DataFrame(data)
scaler=StandardScaler()
scaled_data=scaler.fit_transform(df)
pca=PCA(n_components=2)
pca_result=pca.fit_transform(scaled_data)
pca_df=pd.DataFrame(pca_result,columns=['PCA1','PCA2'])

explained_variance=pca.explained_variance_ratio_
print('variance capture by each pca componet:')
print(np.round(explained_variance*100,2))

plt.figure(figsize=(8,6))
plt.scatter(pca_df['PCA1'],pca_df['PCA2'],color='black')
plt.title('pca projection in 2d view')
plt.xlabel('pca1 main patten')
plt.ylabel('pca2 minor patten')
plt.grid(True)
plt.show()

print('new data with 2 feature pca1 and pca2')
print(pca_df)
# Out:
# variance capture by each pca componet:
# [99.65  0.35]
# new data with 2 feature pca1 and pca2
#        PCA1      PCA2
# 0 -2.901838  0.038962
# 1 -1.703939  0.088054
# 2 -0.585677 -0.001447
# 3  0.452949 -0.229542
# 4  1.730485 -0.041856
# 5  3.008020  0.145829

# %%
df.head()
# Out:
#    Age  Income  Spending  Saving
# 0   25   30000        70    1000
# 1   30   40000        60    5000
# 2   35   50000        50    8000
# 3   40   60000        40   10000
# 4   45   70000        30   15000

# %%
df.head()
# Out:
#    Age  Income  Spending  Saving
# 0   25   30000        70    1000
# 1   30   40000        60    5000
# 2   35   50000        50    8000
# 3   40   60000        40   10000
# 4   45   70000        30   15000

# %%
d.head()
# Out:
#          Name of Student  Roll No.  No. of DSA questions  CGPA Knows ML  \
# 0              Todd Pope     30678                   151  8.52      Yes
# 1           Sandra Brown     49191                    24  1.23      Yes
# 2  Mrs. Amanda Singleton     83519                   333  9.85       No
# 3       Matthew Alvarado     56203                   132  1.96       No
# 4        Christine Smith     82173                   198  9.73      Yes
#
#   Knows DSA Knows Python Knows JavaScript Knows HTML Knows CSS  ... ml python  \
# 0       Yes          Yes              Yes         No       Yes  ...  1      1
# 1        No           No              Yes         No        No  ...  1      0
# 2       Yes          Yes               No        Yes        No  ...  0      1
# 3        No          Yes               No        Yes        No  ...  0      1
# 4       Yes          Yes              Yes        Yes       Yes  ...  1      1
#
#   js html  css  cricker  dance fest  clube  group
# ...

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score,confusion_matrix,mean_absolute_error,mean_squared_error
y_true=[1,0,1,1,0,1,1,0,1,0]
y_pre= [0,1,0,1,0,1,1,0,1,0]
print("Accurecy:",accuracy_score(y_true,y_pre))
print("f1_score:",f1_score(y_true,y_pre))
print("precission:",precision_score(y_true,y_pre))
print("recall:",recall_score(y_true,y_pre))
print("Confusion matrix:",confusion_matrix(y_true,y_pre))
# Out:
# Accurecy: 0.7
# f1_score: 0.7272727272727273
# precission: 0.8
# recall: 0.6666666666666666
# Confusion matrix: [[3 1]
#  [2 4]]

# %%
'''true negative(tn)     false positive(fp)
                       

   false negative(fn)    true positive(tp)
'''
# Out:
# 'true negative(tn)     false positive(fp)\n\n\n   false negative(fn)    true positive(tp)\n'
