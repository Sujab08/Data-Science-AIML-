# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\kumar\Downloads\archive (3).zip")

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=["index","Unnamed: 0"],inplace=True)

# %%
df=df.replace("Nan",np.nan)

# %%
c=df.columns
d=[]
for i in c:
    d.append(i.upper())
df.columns=d

# %%
df["CATEGORY"].unique()
# Out:
# array(['Westernwear-Women', 'Indianwear-Women',
#        'Lingerie&Nightwear-Women', 'Footwear-Women', 'Watches-Women',
#        'Fragrance-Women', 'Jewellery-Women'], dtype=object)

# %%
df["SIZES"]=df["SIZES"].fillna(df["SIZES"].mode()[0])

# %%
df["MRP"].unique()]\
# Out:
# array([ 1699,  3499,  1199, ...,  1080,  1125, 18000], shape=(1097,))

# %%
df["MRP"]=df["MRP"].str.replace("Rs\n","")

# %%
df["MRP"]=df["MRP"].astype(float)

# %%
df["MRP"]=df["MRP"].fillna(round(df["MRP"].mean(),0))

# %%
df["MRP"].mean()
# Out:
# np.float64(2638.2167045910855)

# %%
df["SELLPRICE"]=df["SELLPRICE"].astype(float)

# %%
df["MRP"]=df["MRP"].astype(int)

# %%
df["SELLPRICE"]=df["SELLPRICE"].fillna(round(df["SELLPRICE"].mean(),0))

# %%
df["SELLPRICE"]=df["SELLPRICE"].astype(int)

# %%
df["DISCOUNT"]=df["DISCOUNT"].str.replace("off","")

# %%
df["DISCOUNT"]=df["DISCOUNT"].str.replace("%","")

# %%
df["DISCOUNT"]=df["DISCOUNT"].astype(float)

# %%
df["BRANDNAME"]=df["BRANDNAME"].fillna(df["BRANDNAME"].mode()[0])

# %%
df["DEATILS"]=df["DEATILS"].fillna(df["DEATILS"].mode()[0])

# %%
df["DISCOUNT"]=df["DISCOUNT"].fillna((df["SELLPRICE"]/df["MRP"])*100).tail(40)

# %%
df["DISCOUNT"]=round(df["DISCOUNT"],0)

# %%
df["DISCOUNT"]=df["DISCOUNT"].astype(str)

# %%
df["DISCOUNT"]=df["DISCOUNT"].str.replace(".0","%Off")

# %%
df["DISCOUNT"]=df["DISCOUNT"].str.replace("O","o")

# %%
df.tail(40)
# Out:
#                 BRANDNAME                                            DEATILS  \
# 29387              ayesha         womens stone studded drop earrings - multi
# 29388              jewelz             womens stone silver danglers for women
# 29389              jewelz            ice-cream and new born baby rubber band
# 29390             estelle  womens rhodium plated simple concave hoop earr...
# 29391             estelle  womens gold plated three daisy flower kundan p...
# 29392        michael kors        premium gold womens earrings - mkc1367a1710
# 29393           swarovski          constella crystal womens western necklace
# 29394   daniel wellington                elan triad ring rose gold - size 60
# 29395             estelle  womens gold plated mallika begum kundan earrin...
# 29396               clara  womens 925 sterling silver freya mangalsutra t...
# 29397             estelle  womens gold plated cz mosaic fancy ring (non a...
# ...

# %%
df.isna().sum()
# Out:
# BRANDNAME    0
# DEATILS      0
# SIZES        0
# MRP          0
# SELLPRICE    0
# DISCOUNT     0
# CATEGORY     0
# dtype: int64

# %%
df.describe()
# Out:
#          BRANDNAME                                  DEATILS  \
# count        29420                                    29420
# unique         274                                    23876
# top     vastranand  synthetic womens casual sandals - black
# freq          1467                                       35
#
#                                           SIZES       MRP SELLPRICE DISCOUNT  \
# count                                     23226     22413     29420    22413
# unique                                     1171      1096      2045       65
# top     Size:Large,Medium,Small,X-Large,X-Small  Rs\n1499       499  50% off
# freq                                       1970       925       798     7557
#
#                  CATEGORY
# count               29427
# unique                  7
# top     Westernwear-Women
# freq                 9962

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29427 entries, 0 to 29426
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BRANDNAME  29420 non-null  object
#  1   DEATILS    29420 non-null  object
#  2   SIZES      23226 non-null  object
#  3   MRP        22413 non-null  object
#  4   SELLPRICE  29420 non-null  object
#  5   DISCOUNT   22413 non-null  object
#  6   CATEGORY   29427 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB
