# %%
print("SUJAB")
# Out:
# SUJAB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\kumar\OneDrive\Quikr_car.csv")
df.head(5)
# Out:
#    Unnamed: 0                                          Name     Label  \
# 0           0       Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM
# 1           1        Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM
# 2           2  Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  PLATINUM
# 3           3                          Hyundai Venue - 2019  PLATINUM
# 4           4                             Honda Jazz - 2017  PLATINUM
#
#     Location       Price   Kms_driven Fuel_type       Owner  Year  Company
# 0  Bangalore   ₹3,80,000  35,056 kms     Petrol         NaN  2015     Ford
# 1  Bangalore   ₹4,65,000  44,000 kms     Petrol         NaN  2016   Maruti
# 2  Bangalore  ₹13,50,000  42,917 kms     Petrol         NaN  2018  Hyundai
# 3    Chennai  ₹10,19,699  16,112 kms    Petrol    2nd Owner  2019  Hyundai
# 4       Pune   ₹7,13,499  30,988 kms    Petrol    2nd Owner  2017    Honda

# %%
df['Owner'].unique()
# Out:
# array([nan, ' 2nd Owner', ' 1st Owner', ' 3rd Owner'], dtype=object)

# %%
df.shape
# Out:
# (1032, 10)

# %%
d=df.copy()

# %%
d['Price']=d['Price'].str.replace("₹","")

# %%
d['Price']=d['Price'].str.replace("₹","")

# %%
d['Price']=d['Price'].replace("Ask For Price",np.nan)

# %%
d['Price'].isna().sum()
# Out:
# np.int64(6)

# %%
d['Price']=d['Price'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 d['Price']=d['Price'].astype(float)
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '3,80,000'

# %%
d['Price']=d['Price'].fillna(d['Price'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 d['Price']=d['Price'].fillna(d['Price'].mean())
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\_methods.py:51, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      49 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      50          initial=_NoValue, where=True):
# ---> 51     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
d['Price']=d['Price'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 d['Price']=d['Price'].astype(int)
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '3,80,000'

# %%
d['Kms_driven']=d['Kms_driven'].str.replace("kms","")

# %%
d['Kms_driven']=d['Kms_driven'].str.replace(",","")

# %%
d['Kms_driven']=d['Kms_driven'].astype(int)

# %%
d['Company'].unique()
# Out:
# array(['Ford', 'Maruti', 'Hyundai', 'Honda', 'Toyota', 'Jeep', 'Kia',
#        'Tata', 'Audi', 'Renault', 'BMW', 'Nissan', 'MG', 'Mahindra',
#        'Volkswagen', 'Volvo', 'Skoda', 'Jaguar', 'Mercedes', 'Ssangyong',
#        'Fiat', 'Chevrolet', 'Datsun', 'Land', 'Porsche'], dtype=object)

# %%
d['Fuel_type'].unique()
# Out:
# array([' Petrol', ' Petrol ', ' Diesel ', ' Diesel', ' Electric ', ' CNG',
#        ' LPG', ' Petrol + CNG ', ' Hybrid ', ' CNG '], dtype=object)

# %%
d.head(39)
# Out:
#     Unnamed: 0                                               Name     Label  \
# 0            0            Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM
# 1            1             Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM
# 2            2       Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  PLATINUM
# 3            3                               Hyundai Venue - 2019  PLATINUM
# 4            4                                  Honda Jazz - 2017  PLATINUM
# 5            5                                 Hyundai i20 - 2013  PLATINUM
# 6            6     Maruti Suzuki Swift Dzire VXi 1.2 BS IV - 2015  PLATINUM
# 7            7                  Toyota Corolla Altis VL AT - 2017  PLATINUM
# 8            8                                 Honda Amaze - 2013  PLATINUM
# 9            9                  Hyundai Elite i20 Asta 1.2 - 2017  PLATINUM
# 10          10               Maruti Suzuki Alto 800 Vxi O  - 2018  PLATINUM
# 11          11                                  Honda Jazz - 2018  PLATINUM
# 12          12                        Maruti Suzuki Baleno - 2016  PLATINUM
# 13          13                                Jeep Compass - 2017  PLATINUM
# 14          14            Maruti Suzuki Alto K10 Vxi O AMT - 2017  PLATINUM
# 15          15                                  Kia Seltos - 2019  PLATINUM
# 16          16           Toyota Innova 2.5 VX BS III 7 STR - 2012      GOLD
# 17          17               Hyundai Elite i20 ASTA 1.2 O  - 2016      GOLD
# 18          18         Hyundai Creta 1.6 CRDI SX PLUS AUTO - 2019      GOLD
# 19          19                                  Kia Seltos - 2020      GOLD
# 20          20            Maruti Suzuki Ciaz DELTA 1.4 VVT - 2017      GOLD
# 21          21          Ford EcoSport Titanium 1.5L Ti VCT - 2019      GOLD
# 23    Chennai  ₹18,50,000    76,000 kms     Diesel         NaN  2011     Audi
# 24       Pune   ₹8,07,499    23,698 kms    Petrol    1st Owner  2017     Ford
# 25       Pune   ₹5,22,999    37,860 kms    Petrol    2nd Owner  2016  Hyundai
# 26       Pune   ₹4,74,299    91,830 kms    Petrol    2nd Owner  2015   Maruti
# 27       Pune   ₹7,40,899    31,172 kms    Petrol    2nd Owner  2019  Hyundai
# 28       Pune  ₹11,41,999     3,243 kms    Petrol    2nd Owner  2021   Toyota
# 29       Pune   ₹9,71,299     9,616 kms    Petrol    2nd Owner  2020     Tata
# 30       Pune   ₹6,40,999    30,249 kms    Petrol    2nd Owner  2017   Maruti
# 31       Pune   ₹6,76,199    60,875 kms    Petrol    2nd Owner  2019   Maruti
# 32    Chennai   ₹5,62,399    25,740 kms    Petrol    2nd Owner  2017   Maruti
# 33       Pune   ₹5,80,899    38,587 kms    Petrol    2nd Owner  2014     Ford
# 34       Pune   ₹7,70,999     3,108 kms    Petrol    2nd Owner  2021  Renault
# 35       Pune   ₹5,31,399    35,353 kms    Petrol    2nd Owner  2016    Honda
# 36       Pune   ₹3,67,299    34,748 kms    Petrol    2nd Owner  2017  Hyundai
# 37       Pune   ₹4,12,199     2,359 kms    Petrol    2nd Owner  2020   Maruti
# 38       Pune  ₹14,60,099    17,814 kms    Diesel    2nd Owner  2020  Hyundai

# %%
q1=d['Price'].quantile(0.25)
q3=d['Price'].quantile(0.75)
q1,q3
# Out:
# (np.float64(411774.0), np.float64(786949.0))

# %%
IQR=q3-q1
IQR
# Out:
# np.float64(375175.0)

# %%
min=q1-(1.5*IQR)
max=q3+(1.5*IQR)
min,max
# Out:
# (np.float64(-150988.5), np.float64(1349711.5))

# %%
d.shape
# Out:
# (1032, 10)

# %%
dd=d[d['Price']<max]

# %%
Q1=d['Kms_driven'].quantile(0.25)
Q3=d['Kms_driven'].quantile(0.75)
Q1,Q3
# Out:
# (np.float64(26327.75), np.float64(67663.75))

# %%
iqr=Q3-Q1
iqr
# Out:
# np.float64(41336.0)

# %%
MIN=Q1-(1.5*iqr)
MAX=Q3+(1.5*iqr)
MIN,MAX
# Out:
# (np.float64(-35676.25), np.float64(129667.75))

# %%
ddd=dd[dd['Kms_driven']<MAX]

# %%
ddd.shape
# Out:
# (912, 10)

# %%
ddd['Price'].max()
# Out:
# np.int64(1325000)

# %%
ddd['Price'].mean()
# Out:
# np.float64(561561.95)

# %%
ddd['Price'].min()
# Out:
# np.int64(39000)

# %%
ddd['Price'].std()
# Out:
# np.float64(251396.52853646144)

# %%
dd['Location'].unique()
# Out:
# array(['Bangalore'], dtype=object)

# %%
dd.head(30)
# Out:
#     Unnamed: 0                                               Name     Label  \
# 0            0            Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM
# 1            1             Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM
# 3            3                               Hyundai Venue - 2019  PLATINUM
# 4            4                                  Honda Jazz - 2017  PLATINUM
# 5            5                                 Hyundai i20 - 2013  PLATINUM
# 6            6     Maruti Suzuki Swift Dzire VXi 1.2 BS IV - 2015  PLATINUM
# 41  Bangalore   890000       81000    Diesel   2nd Owner  2010      BMW
# 42  Bangalore   245000       80000   Diesel    2nd Owner  2012   Nissan
# 43  Bangalore   945000       12000    Petrol   2nd Owner  2020   Toyota
# 44  Bangalore   590000        6000    Petrol   2nd Owner  2016   Maruti
# 45  Bangalore   495000       56000    Petrol   2nd Owner  2017    Honda

# %%
ddd['Location']
# Out:
# Location
# Bangalore    912
# Name: count, dtype: int64

# %% [markdown]
# # linear regression example

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
X=ddd[['Kms_driven','Year']]
y=ddd['Price']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
result=lr.predict(X_test)
print("mse:",mean_squared_error(y_test,result))
print("mae:",mean_absolute_error(y_test,result))
print("rmse:",np.sqrt(mean_squared_error(y_test,result)))
print("R2score:",r2_score(y_test,result))
# Out:
# mse: 41150487264.87819
# mae: 151375.61453964483
# rmse: 202855.82876732477
# R2score: 0.2737729803993608

# %%
X_test,y_test
# Out:
# (     Kms_driven  Year
#  735      101920  2016
#  861      125000  2003
#  621       45000  2007
#  423        1405  2021
#  417       10890  2017
#  ..          ...   ...
#  801       24484  2019
#  729       51886  2014
#  350       47564  2015
#  8         44940  2013
#  291       12500  2015
#
#  [228 rows x 2 columns],
#  735    588099
#  861     74999
#  621    130000
#  423    491499
#  417    535899
#          ...
#  801    473699
#  729    409399
#  350    411399
#  8      393699
#  291    740000
#  Name: Price, Length: 228, dtype: int64)

# %%
result=lr.predict([[24484,2019]])
result
# Out:
# c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([698236.12693936])

# %%
plt.figure(figsize=[20,6])
plt.subplot(1,2,1)
sns.boxplot(x=ddd['Price'])
plt.subplot(1,2,2)
sns.boxplot(x=ddd['Kms_driven'])
plt.show()

# %%
plt.figure(figsize=[20,6])
plt.subplot(1,2,1)
sns.boxplot(x=d['Price'])
plt.subplot(1,2,2)
sns.boxplot(x=d['Kms_driven'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=[20,6])
#       2 plt.subplot(1,2,1)
#       3 sns.boxplot(x=d['Price'])
#
# NameError: name 'plt' is not defined

# %%
d['Location']=d['Location'].fillna(d['Location'].mode())[0]

# %%
d['Owner']=d['Owner'].fillna(d['Owner'].mode())[0]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1032 non-null   int64
#  1   Name        1032 non-null   object
#  2   Label       1032 non-null   object
#  3   Location    1032 non-null   object
#  4   Price       1032 non-null   int64
#  5   Kms_driven  1032 non-null   int64
#  6   Fuel_type   1032 non-null   object
#  7   Owner       1032 non-null   object
#  8   Year        1032 non-null   int64
#  9   Company     1032 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 80.8+ KB

# %%
d.describe()
# Out:
#         Unnamed: 0         Price     Kms_driven         Year
# count  1032.000000  1.032000e+03    1032.000000  1032.000000
# mean    515.500000  6.857131e+05   50398.250969  2015.810078
# std     298.057042  5.359092e+05   38159.221815     3.396920
# min       0.000000  3.900000e+04       0.000000  2000.000000
# 25%     257.750000  4.117740e+05   26327.750000  2014.000000
# 50%     515.500000  5.595495e+05   44000.000000  2016.000000
# 75%     773.250000  7.869490e+05   67663.750000  2018.000000
# max    1031.000000  7.500000e+06  690000.000000  2022.000000
