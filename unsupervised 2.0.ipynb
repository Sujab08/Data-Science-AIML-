# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\kumar\Downloads\IMB575-XLS-ENG.csv")

# %%
data.head(2)
# Out:
#     Description
# 0  Other Sauces
# 1       Cashews

# %%
data=df.copy()

# %%
data.drop(columns="Member",inplace=True)

# %%
data.shape[0]
# Out:
# 62141

# %%
data.columns
# Out:
# Index(['Description'], dtype='object')

# %%
data["Description"][1]
# Out:
# 'Cashews'

# %%
list=[]
for i in range (0,data.shape[0]):
    for j in data.columns:
        list.append(data["Description"][i])

# %%
import collections

# %%
p=collections.Counter(list)

# %%
sim={"product":p.keys(),"values":p.values()}

# %%
sup=pd.DataFrame(sim)

# %%
suj=sup.sort_values(by="values",ascending=False)

# %%
data["Description"].value_counts()
# Out:
# Description
# Other Vegetables             4606
# Beans                        4549
# Root Vegetables              4303
# Other Dals                   3272
# Organic F&V                  3113
#                              ...
# Body Lotion                     1
# Talc                            1
# Eye Care & Kajal                1
# Cookery Books                   1
# Dishwash Liquids & Pastes       1
# Name: count, Length: 216, dtype: int64

# %%
suj.head(10)
# Out:
#              product  values
# 20  Other Vegetables    4606
# 27             Beans    4549
# 19   Root Vegetables    4303
# 2         Other Dals    3272
# 32       Organic F&V    3113
# 25      Whole Spices    3001
# 47  Gourd & Cucumber    2973
# 49          Brinjals    2569
# 3            Namkeen    2224
# 5             Banana    2188
