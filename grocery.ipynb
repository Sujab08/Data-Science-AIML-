# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\kumar\Downloads\aisles.csv")

# %%
data.head(10)
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
# 5         6                       other
# 6         7               packaged meat
# 7         8             bakery desserts
# 8         9                 pasta sauce
# 9        10            kitchen supplies

# %%
list=[]
for i in range(0,data.shape[0]):
    list.append(data["aisle"][i])

# %%
import collections

# %%
p=collections.Counter(list)

# %%
d={"product":p.keys(),"count":p.values()}

# %%
seema=pd.DataFrame(d)

# %%
seema.sort_values(by=["product"],ascending=False)
# Out:
#                            product  count
# 119                         yogurt      1
# 61                     white wines      1
# 114  water seltzer sparkling water      1
# 46            vitamins supplements      1
# 59               trash bags liners      1
# ..                             ...    ...
# 91               baby food formula      1
# 101            baby bath body care      1
# 81                baby accessories      1
# 65                     asian foods      1
# 100         air fresheners candles      1
#
# [134 rows x 2 columns]

# %%
df=pd.read_csv(r"C:\Users\kumar\Downloads\Supermart Grocery Sales - Retail Analytics Dataset.csv")

# %%
df.head()
# Out:
#   Order ID Customer Name          Category      Sub Category         City  \
# 0      OD1        Harish      Oil & Masala           Masalas      Vellore
# 1      OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#    Order Date Region  Sales  Discount  Profit       State
# 0  11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1  11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2  06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3  10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4  10-11-2016  South   2355      0.26  918.45  Tamil Nadu

# %%
x=df[["Category","Sub Category"]]

# %%
x.shape
# Out:
# (9994, 2)

# %%
x.head()
# Out:
#            Category      Sub Category
# 0      Oil & Masala           Masalas
# 1         Beverages     Health Drinks
# 2       Food Grains      Atta & Flour
# 3  Fruits & Veggies  Fresh Vegetables
# 4       Food Grains   Organic Staples

# %%
s=[]
for i in range(0,x.shape[0]):
    d=[]
    for j in x.columns:
         d.append(x[j][i])
    s.append(d)

# %%
list=[]
for i in s:
    for j in i:
        list.append(j)

# %%
f=collections.Counter(list)

# %%
z={"product":f.keys(),"frequently buyes":f.values()}

# %%
ku=pd.DataFrame(z)

# %%
ku.sort_values(by=["frequently buyes"],ascending=False)
# Out:
#                product  frequently buyes
# 13              Snacks              1514
# 15   Eggs, Meat & Fish              1490
# 6     Fruits & Veggies              1418
# 10              Bakery              1413
# 2            Beverages              1400
# 4          Food Grains              1398
# 0         Oil & Masala              1361
# 3        Health Drinks               719
# 21         Soft Drinks               681
# 17             Cookies               520
# 29       Breads & Buns               502
# 14          Chocolates               499
# 24             Noodles               495
# 1              Masalas               463
# 11            Biscuits               459
# 12               Cakes               452
# 19   Edible Oil & Ghee               451
# 27              Spices               447
# 20              Mutton               394
# 16                Eggs               379
# 8      Organic Staples               372
# 9         Fresh Fruits               369
# ...

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr=TransactionEncoder()

# %%
tr.fit(s)
# Out:
# TransactionEncoder()

# %%
 zz=pd.DataFrame(tr.transform(s),columns=tr.columns_)

# %%
zz
# Out:
#       Atta & Flour  Bakery  Beverages  Biscuits  Breads & Buns  Cakes  \
# 0            False   False      False     False          False  False
# 1            False   False       True     False          False  False
# 2             True   False      False     False          False  False
# 3            False   False      False     False          False  False
# 4            False   False      False     False          False  False
# ...            ...     ...        ...       ...            ...    ...
# 9989         False   False      False     False          False  False
# 9990         False    True      False      True          False  False
# 9991         False   False      False     False          False  False
# 9992         False   False      False     False          False  False
# 9993          True   False      False     False          False  False
#
#       Chicken  Chocolates  Cookies  Dals & Pulses  ...  Mutton  Noodles  \
# ...

# %%
from mlxtend.frequent_patterns import apriori

# %%
apriori(zz,min_support=0.03,use_colnames=True,max_len=3).sort_values(by=["support"],ascending=False)
# Out:
#      support                                itemsets
# 27  0.151491                                (Snacks)
# 12  0.149089                     (Eggs, Meat & Fish)
# 17  0.141885                      (Fruits & Veggies)
# 1   0.141385                                (Bakery)
# 2   0.140084                             (Beverages)
# 14  0.139884                           (Food Grains)
# 22  0.136182                          (Oil & Masala)
# 18  0.071943                         (Health Drinks)
# 34  0.071943              (Beverages, Health Drinks)
# 28  0.068141                           (Soft Drinks)
# 35  0.068141                (Beverages, Soft Drinks)
# 38  0.052031                       (Snacks, Cookies)
# 8   0.052031                               (Cookies)
# 4   0.050230                         (Breads & Buns)
# 32  0.050230                 (Bakery, Breads & Buns)
# 37  0.049930                    (Snacks, Chocolates)
# 7   0.049930                            (Chocolates)
# ...

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
fpgrowth(zz,min_support=0.03,max_len=3,use_colnames=True).sort_values(by=["support"],ascending=False)
# Out:
#      support                                itemsets
# 13  0.151491                                (Snacks)
# 15  0.149089                     (Eggs, Meat & Fish)
# 6   0.141885                      (Fruits & Veggies)
# 10  0.141385                                (Bakery)
# 2   0.140084                             (Beverages)
# 4   0.139884                           (Food Grains)
# 0   0.136182                          (Oil & Masala)
# 3   0.071943                         (Health Drinks)
# 31  0.071943              (Beverages, Health Drinks)
# 21  0.068141                           (Soft Drinks)
# 44  0.068141                (Beverages, Soft Drinks)
# 40  0.052031                       (Snacks, Cookies)
# 17  0.052031                               (Cookies)
# 52  0.050230                 (Bakery, Breads & Buns)
# 29  0.050230                         (Breads & Buns)
# 14  0.049930                            (Chocolates)
# 38  0.049930                    (Snacks, Chocolates)
# ...
