# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\kumar\Downloads\extended_flower_morphometrics.csv")
df=data.copy()

# %%
df.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0         4.317614        3.028292         6.092543        3.166156
# 1         5.531122        3.887679         5.497682        2.374855
# 2         5.908407        2.576321         6.264473        1.785481
# 3         6.855284        2.764075         4.606390        1.175031
# 4         5.412124        3.691987         1.800383        0.221225
#
#    stem_thickness_mm  petal_density_pct  chlorophyll_index  native_altitude_m  \
# 0           5.063025          63.558150          55.913100         886.568622
# 1           4.656235          52.368783          26.383116         247.206553
# 2           5.893707          36.056153          61.562376        1197.921681
# 3           4.854951          55.623467          38.671083         940.401196
# 4           2.528513          60.218904          34.674831         679.473136
#
#            species
# 0             Rose
# 1  Iris Versicolor
# 2           Orchid
# ...

# %%
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# count    200000.000000   200000.000000    200000.000000   200000.000000
# mean          6.494801        3.701722         5.660341        2.339627
# std           2.389844        1.219015         3.769632        1.761005
# min           1.314396       -0.681257        -0.040491       -1.097662
# 25%           4.976431        2.955377         3.371251        1.137561
# 50%           5.732968        3.406310         4.901882        2.118828
# 75%           6.973427        4.003575         6.466747        3.107515
# max          18.797057       11.130567        24.222782       10.444469
#
#        stem_thickness_mm  petal_density_pct  chlorophyll_index  \
# count      200000.000000      200000.000000      200000.000000
# mean            6.756894          53.202820          45.769422
# std             4.301134          13.891707          10.579623
# min            -1.357669          -0.531327           2.766288
# ...

# %%
q1=df["sepal_length_cm"].quantile(0.25)
q3=df["sepal_length_cm"].quantile(0.75)
IQR=q3-q1
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)1

# %%
q1=df["sepal_width_cm"].quantile(0.25)
q3=df["sepal_width_cm"].quantile(0.75)
IQR=q3-q1
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)2

# %%
q1=df["petal_length_cm"].quantile(0.25)
q3=df["petal_length_cm"].quantile(0.75)
IQR=q3-q1
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)3

# %%
q1=df["petal_width_cm"].quantile(0.25)
q3=df["petal_width_cm"].quantile(0.75)
IQR=q3-q1
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)4

# %%
q1=df["stem_thickness_mm"].quantile(0.25)
q3=df["stem_thickness_mm"].quantile(0.75)
IQR=q3-q1
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)

# %%
q1=df["petal_density_pct"].quantile(0.25)
q3=df["petal_density_pct"].quantile(0.75)
IQR=q3-q1
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)

# %%
q1=df["chlorophyll_index"].quantile(0.25)
q3=df["chlorophyll_index"].quantile(0.75)
IQR=q3-q1
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)

# %%
q1=df["native_altitude_m"].quantile(0.25)
q3=df["native_altitude_m"].quantile(0.75)
IQR=q3-q1
min=q1-(IQR*1.5)
max=q3+(IQR*1.5)

# %%
df=df[(df["chlorophyll_index"]>min)&(df["chlorophyll_index"]<max)]

# %%
df.shape
# Out:
# (200000, 9)

# %%
df.columns
# Out:
# Index(['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm',
#        'petal_width_cm', 'stem_thickness_mm', 'petal_density_pct',
#        'chlorophyll_index', 'native_altitude_m', 'species'],
#       dtype='object')

# %%
plt.figure(figsize=(11,7))
plt.subplot(1,2,1)
sns.boxplot(x="native_altitude_m",data=data)
plt.title("before clean")
plt.subplot(1,2,2)
sns.boxplot(x="native_altitude_m",data=df)
plt.title("after clean")
plt.show()

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns="index",inplace=True)

# %%
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# count    200000.000000   200000.000000    200000.000000   200000.000000
# mean          6.494801        3.701722         5.660341        2.339627
# std           2.389844        1.219015         3.769632        1.761005
# min           1.314396       -0.681257        -0.040491       -1.097662
# 25%           4.976431        2.955377         3.371251        1.137561
# 50%           5.732968        3.406310         4.901882        2.118828
# 75%           6.973427        4.003575         6.466747        3.107515
# max          18.797057       11.130567        24.222782       10.444469
#
#        stem_thickness_mm  petal_density_pct  chlorophyll_index  \
# count      200000.000000      200000.000000      200000.000000
# mean            6.756894          53.202820          45.769422
# std             4.301134          13.891707          10.579623
# min            -1.357669          -0.531327           2.766288
# ...

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()

# %%
sc.fit(x)
# Out:
# MinMaxScaler()

# %%
Sc=sc.transform(x)

# %%
X=pd.DataFrame(Sc,columns=x.columns)

# %%
X
# Out:
#         sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              0.171783        0.314054         0.252770        0.369413
# 1              0.241195        0.386810         0.228253        0.300856
# 2              0.262775        0.275790         0.259856        0.249793
# 3              0.316936        0.291685         0.191519        0.196904
# 4              0.234388        0.370243         0.075871        0.114267
# ...                 ...             ...              ...             ...
# 199995         0.171365        0.328901         0.191598        0.370783
# 199996         0.236059        0.272764         0.128021        0.362113
# 199997         0.361502        0.287714         0.229491        0.142304
# 199998         0.258911        0.224902         0.366624        0.273812
# 199999         0.278147        0.328687         0.178535        0.290360
#
#         stem_thickness_mm  petal_density_pct  chlorophyll_index  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
gs=GaussianNB()
gs.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
print(gs.score(X_train,y_train),gs.score(X_test,y_test))
# Out:
# 0.8235375 0.8263
