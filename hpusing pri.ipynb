# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\kumar\Downloads\house_price_regression_dataset.csv")

# %%
df=data.copy()

# %%
df=df.astype(int)

# %%
df.head(2)
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981         0
# 1            4272             3              3        2016         4
#
#    Garage_Size  Neighborhood_Quality  House_Price
# 0            0                     5       262382
# 1            1                     6       985260

# %%
sns.pairplot(data=df)
plt.show()

# %%
x=df[["Square_Footage","Num_Bedrooms","Num_Bathrooms","Year_Built","Lot_Size","Garage_Size","Neighborhood_Quality"]]
y=df["House_Price"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test,lr.predict(x_test)))
# Out:
# np.float64(10805.206032972883)

# %%
lr.score(x_test,y_test)*100
# Out:
# 99.81887282775213

# %%
mean_absolute_error(y_test,lr.predict(x_test))
# Out:
# 8831.49753711435

# %%
x_test.head(10)
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 521            4012             3              1        2016         2
# 737            2310             3              1        1988         1
# 740            4708             1              3        1962         1
# 660            4932             2              1        1972         4
# 411            3646             1              1        1994         3
# 678            3586             2              2        1964         2
# 626            4638             4              3        2000         1
# 513            4127             5              2        1992         1
# 859            3781             2              1        1989         3
# 136            4243             2              1        2002         4
#
#      Garage_Size  Neighborhood_Quality
# 521            1                     5
# 737            1                     4
# 740            1                     8
# 660            1                     2
# 411            0                     9
# 678            0                    10
# 626            1                     3
# 513            2                     1
# 859            0                     9
# 136            2                     7

# %%
df["House_Price"][521]
# Out:
# np.int64(901000)

# %%
lr.predict([[4012,3,1,2016,2,1,5]]).astype(int)
# Out:
# c:\Users\kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([876021])

# %%
r2_score(y_test,lr.predict(x_test))
# Out:
# 0.9981887282775213

# %%
#lr.predict([[]])

# %%
from sklearn.svm import SVR

# %%
svm=SVR(kernel='linear')
svm.fit(x_train,y_train)
svm.score(x_test,y_test)
# Out:
# 0.9883153958599161

# %%
np.sqrt(mean_squared_error(y_test,svm.predict(x_test)))
# Out:
# np.float64(27444.05308540165)

# %%
from sklearn.tree import DecisionTreeRegressor
dc=DecisionTreeRegressor(max_depth=5)
dc.fit(x_train,y_train)
dc.score(x_test,y_test)
# Out:
# 0.9792908078964472

# %%
np.sqrt(mean_squared_error(y_test,dc.predict(x_test)))
# Out:
# np.float64(36536.153842412234)

# %%
from sklearn.neighbors import KNeighborsRegressor
kn=KNeighborsRegressor()
kn.fit(x_train,y_train)
kn.score(x_test,y_test)
# Out:
# 0.9837003980358907

# %%
np.sqrt(mean_squared_error(y_test,kn.predict(x_test)))
# Out:
# np.float64(32413.78509828496)
